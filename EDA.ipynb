# %% [markdown]
# # The Spark Foundation
# # Stream: Data Science and Business Analytics
# # Task 4: Exploratory Data Analysis - Terrorism
# ###                (Level - Intermediate)
# ## Presented By : Tharun Guduguntla

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os
from pandas import DataFrame

# %% [markdown]
# ### Lets see what data is stored in the given file

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
pd.set_option('display.max_columns', 999)
df.head()
# Out:
# /Users/rentomojo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1        0.0          NaN             NaN
# 1     NaN      1      1      1        0.0          NaN             NaN
# 2     NaN      1      1      1        0.0          NaN             NaN
# 3     NaN      1      1      1        0.0          NaN             NaN
# 4     NaN      1      1      1       -9.0          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN         0         NaN            NaN        NaN         NaN
# 1       NaN         0         NaN            NaN        NaN         NaN
# 2       NaN         0         NaN            NaN        NaN         NaN
# 3       NaN         1         NaN            NaN        NaN         NaN
# 4       NaN         1         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS        0         0         0        0     NaN
# 1     PGIS        0         1         1        1     NaN
# 2     PGIS       -9        -9         1        1     NaN
# 3     PGIS       -9        -9         1        1     NaN
# 4     PGIS       -9        -9         1        1     NaN

# %% [markdown]
# ### This data is so clumpsy with so many columns and so many NAN values

# %% [markdown]
# #### Lets rename the columns

# %%
df.rename(columns = {'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','city':'City','latitude':'Latitude','longitude':'Longitude','location':'Location', 'success':'Success','suicide':'Suicide','attacktype1_txt':'Attack_Type','targtype1_txt':'Target_Type','targsubtype1_txt':'Target_Sub_Type','corp1':'Corporation','target1':'Target','natlty1_txt':'Target_Nation','weaptype1_txt':'Weapon_Type','weapsubtype1_txt':'Weapon_Sub_Type','weapdetail':'Weapon_detail','nkill':'Killed','nwound':'Wounded'},inplace=True)
df= df[['Year','Month','Day','Country','Region','City','Latitude','Longitude','Location','Success','Suicide','Attack_Type','Target_Type','Target_Sub_Type','Corporation','Target','Target_Nation','Weapon_Type','Weapon_Sub_Type','Weapon_detail','Killed','Wounded']]
df.head(20)
# Out:
#     Year  Month  Day             Country                       Region  \
# 0   1970      7    2  Dominican Republic  Central America & Caribbean
# 1   1970      0    0              Mexico                North America
# 2   1970      1    0         Philippines               Southeast Asia
# 3   1970      1    0              Greece               Western Europe
# 4   1970      1    0               Japan                    East Asia
# 5   1970      1    1       United States                North America
# 6   1970      1    2             Uruguay                South America
# 7   1970      1    2       United States                North America
# 8   1970      1    2       United States                North America
# 9   1970      1    3       United States                North America
# 10  1970      1    1       United States                North America
# 11  1970      1    6       United States                North America
# 12  1970      1    8               Italy               Western Europe
# 13  1970      1    9       United States                North America
# 14  1970      1    9       United States                North America
# 15  1970      1   10  East Germany (GDR)               Eastern Europe
# 16  1970      1   11            Ethiopia           Sub-Saharan Africa
# 17  1970      1   12       United States                North America
# 18  1970      1   12       United States                North America
# 19  1970      1   13       United States                North America
#
#              City   Latitude   Longitude                 Location  Success  \
# 0   Santo Domingo  18.456792  -69.951164                      NaN        1
# 1     Mexico city  19.371887  -99.086624                      NaN        1
# 2         Unknown  15.478598  120.599741                      NaN        1
# 3          Athens  37.997490   23.762728                      NaN        1
# 4         Fukouka  33.580412  130.396361                      NaN        1
# 5           Cairo  37.005105  -89.176269                      NaN        1
# 6      Montevideo -34.891151  -56.187214                      NaN        0
# 7         Oakland  37.791927 -122.225906          Edes Substation        1
# 8         Madison  43.076592  -89.412488                      NaN        1
# 9         Madison  43.072950  -89.386694                      NaN        1
# 10        Baraboo  43.468500  -89.744299                      NaN        0
# 11         Denver  39.758968 -104.876305                      NaN        1
# 12           Rome  41.890961   12.490069                      NaN        1
# 13        Detroit  42.331685  -83.047924                      NaN        1
# 14    Rio Piedras  18.386932  -66.061127  Caparra Shopping Center        1
# 15         Berlin  52.501530   13.401851                      NaN        1
# 16        Unknown        NaN         NaN                      NaN        1
# 17  New York City  40.697132  -73.931351                 Brooklyn        1
# 18     Rio Grande  18.379998  -65.830948                      NaN        1
# 19        Seattle  47.610786 -122.331306                      NaN        1
#
#     Suicide                     Attack_Type                  Target_Type  \
# 0         0                   Assassination  Private Citizens & Property
# 1         0     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2         0                   Assassination          Journalists & Media
# 3         0               Bombing/Explosion      Government (Diplomatic)
# 4         0  Facility/Infrastructure Attack      Government (Diplomatic)
# 5         0                   Armed Assault                       Police
# 6         0                   Assassination                       Police
# 7         0               Bombing/Explosion                    Utilities
# 8         0  Facility/Infrastructure Attack                     Military
# 9         0  Facility/Infrastructure Attack         Government (General)
# 10        0               Bombing/Explosion                     Military
# 11        0  Facility/Infrastructure Attack                     Military
# 12        0                       Hijacking          Airports & Aircraft
# 13        0  Facility/Infrastructure Attack         Government (General)
# 14        0  Facility/Infrastructure Attack                     Business
# 15        0               Bombing/Explosion         Government (General)
# 16        0                         Unknown                     Military
# 17        0               Bombing/Explosion      Educational Institution
# 18        0               Bombing/Explosion                     Business
# 19        0  Facility/Infrastructure Attack                     Business
#
#                                       Target_Sub_Type  \
# 0                                      Named Civilian
# 1   Diplomatic Personnel (outside of embassy, cons...
# 2                     Radio Journalist/Staff/Facility
# 3                                   Embassy/Consulate
# 4                                   Embassy/Consulate
# 5     Police Building (headquarters, station, school)
# 6                     Police Security Forces/Officers
# 7                                         Electricity
# 8                 Military Recruiting Station/Academy
# 9                 Government Building/Facility/Office
# 10      Military Barracks/Base/Headquarters/Checkpost
# 11                Military Recruiting Station/Academy
# 12                       Aircraft (not at an airport)
# 13                Government Building/Facility/Office
# 14                              Retail/Grocery/Bakery
# 15                                                NaN
# 16  Military Personnel (soldiers, troops, officers...
# 17             School/University/Educational Building
# 18                          Multinational Corporation
# 19                              Retail/Grocery/Bakery
#
#                                Corporation  \
# 0                                      NaN
# 1              Belgian Ambassador Daughter
# 2                         Voice of America
# 3                                      NaN
# 4                                      NaN
# 5                  Cairo Police Department
# 6                         Uruguayan Police
# 7           Pacific Gas & Electric Company
# 8                                 R.O.T.C.
# 9                        Selective Service
# 10                                     NaN
# 11                 Army Recruiting Station
# 12                     Trans World Airline
# 13                 U.S. Government housing
# 14  American owned business in Puerto Rico
# 15                                     NaN
# 16                               U.S. Army
# 17                             High School
# 18                        General Electric
# 19                Fuson's Department Store
#
#                                                Target       Target_Nation  \
# 0                                        Julio Guzman  Dominican Republic
# 1                             Nadine Chaval, daughter             Belgium
# 2                                            Employee       United States
# 3                                        U.S. Embassy       United States
# 4                                      U.S. Consulate       United States
# 5                           Cairo Police Headquarters       United States
# 6   Juan Maria de Lucah/Chief of Directorate of in...             Uruguay
# 7                                     Edes Substation       United States
# 8   R.O.T.C. offices at University of Wisconsin, M...       United States
# 9   Selective Service Headquarters in Madison Wisc...       United States
# 10                            Badger Army ammo depot.       United States
# 11           Army Recruiting Station, Denver Colorado       United States
# 12                              Flight 802 Boeing 707       United States
# 13    Packard Properties building of Detroit Michigan       United States
# 14                                      Baker's Store       United States
# 15                 Jurists Ball (Palais au Frankturm)             Germany
# 16                                            Soldier       United States
# 17                          James Madison High School       United States
# 18  General Electric factory in Rio Grande Puerto ...       United States
# 19       Fuson's Department Store, Seattle Washington       United States
#
#    Weapon_Type                    Weapon_Sub_Type  \
# 0      Unknown                                NaN
# 1      Unknown                                NaN
# 2      Unknown                                NaN
# 3   Explosives             Unknown Explosive Type
# 4   Incendiary                                NaN
# 5     Firearms                   Unknown Gun Type
# 6     Firearms  Automatic or Semi-Automatic Rifle
# 7   Explosives             Unknown Explosive Type
# 8   Incendiary       Molotov Cocktail/Petrol Bomb
# 9   Incendiary                Gasoline or Alcohol
# 10  Explosives             Unknown Explosive Type
# 11  Incendiary       Molotov Cocktail/Petrol Bomb
# 12    Firearms      Rifle/Shotgun (non-automatic)
# 13  Incendiary       Molotov Cocktail/Petrol Bomb
# 14  Incendiary                         Arson/Fire
# 15  Explosives             Unknown Explosive Type
# 16     Unknown                                NaN
# 17  Explosives                          Pipe Bomb
# 18  Explosives             Unknown Explosive Type
# 19  Incendiary       Molotov Cocktail/Petrol Bomb
#
#                                         Weapon_detail  Killed  Wounded
# 0                                                 NaN     1.0      0.0
# 1                                                 NaN     0.0      0.0
# 2                                                 NaN     1.0      0.0
# 3                                           Explosive     NaN      NaN
# 4                                          Incendiary     NaN      NaN
# 5                        Several gunshots were fired.     0.0      0.0
# 6                                   Automatic firearm     0.0      0.0
# 7                                                 NaN     0.0      0.0
# 8                     Firebomb consisting of gasoline     0.0      0.0
# 9   Poured gasoline on the floor and lit it with a...     0.0      0.0
# 10                                          Explosive     0.0      0.0
# 11                                   Molotov cocktail     0.0      0.0
# 12                           Rifle - carbine; Pistols     0.0      0.0
# 13                                           Firebomb     0.0      0.0
# 14                          Fire set in back of store     0.0      0.0
# 15                                          Explosive     NaN      NaN
# 16                                                NaN     1.0      0.0
# 17  Crudely made pipe bomb.  Five inches long and ...     0.0      0.0
# 18                                               Bomb     0.0      0.0
# 19                                           Firebomb     0.0      0.0

# %% [markdown]
# ### Many columns are unncessary so remove them

# %%
df.drop(['Target_Sub_Type','Corporation','Target','Target_Nation','Weapon_Sub_Type','Weapon_detail','Location'], axis = 1, inplace=True)
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# Success            0
# Suicide            0
# Attack_Type        0
# Target_Type        0
# Weapon_Type        0
# Killed         10313
# Wounded        16311
# dtype: int64

# %% [markdown]
# ### Most attacks as per contries

# %%
plt.subplots(figsize=(10,6))
country_attacks = df.Country.value_counts()[:10].reset_index()
country_attacks.columns = ['Country','Attacks']
sns.barplot(x=country_attacks.Country, y=country_attacks['Attacks'],palette='OrRd_r',edgecolor=sns.color_palette('dark',15))
plt.xticks(rotation=45)
plt.title('Number of Total Attacks in Each Country',size=20)
plt.show()

# %% [markdown]
# ### Raise of attacks in past 45 years

# %%
plt.subplots(figsize=(10,6))
sns.countplot('Year',data=df,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Total Attacks in Each Year',size=20)
plt.show()
# Out:
# /Users/rentomojo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### All types of weapons used

# %%
weapons = df['Weapon_Type'].value_counts()
weapons = DataFrame(weapons)

weapons.reset_index(level=0, inplace=True)
weapons.columns = ['Weapon used', 'Weapon Count']
weapons
# Out:
#                                           Weapon used  Weapon Count
# 0                                          Explosives         92426
# 1                                            Firearms         58524
# 2                                             Unknown         15157
# 3                                          Incendiary         11135
# 4                                               Melee          3655
# 5                                            Chemical           321
# 6                                  Sabotage Equipment           141
# 7   Vehicle (not to include vehicle-borne explosiv...           136
# 8                                               Other           114
# 9                                          Biological            35
# 10                                       Fake Weapons            33
# 11                                       Radiological            14

# %% [markdown]
# ### Most number of weapons used for the attacks

# %%
weapons.plot.bar(x='Weapon used', y='Weapon Count', rot=60,color = 'r')
# Out:
# <AxesSubplot:xlabel='Weapon used'>

# %% [markdown]
# ### Suicides count with Years

# %%
Suicides_by_year= df[['Year','Suicide']].groupby('Year').aggregate(np.sum)
Suicides_by_year.plot(color = 'r')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # THANK YOU
